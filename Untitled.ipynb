# %%
import openpyxl
import numpy as np
import pandas as pd
from openpyxl.utils.dataframe import dataframe_to_row
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-01bdb06110f7> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from openpyxl.utils.dataframe import dataframe_to_row
#
# ImportError: cannot import name 'dataframe_to_row' from 'openpyxl.utils.dataframe' (C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\utils\dataframe.py)

# %%
df = pd.read_excel('TCR.xlsx', sheet_name='PA_final_table')
df
# Out:
#          TRBV     TRBJ             CDR3β     TRAV    TRAJ            CDR3α  \
# 0      TRBV17  TRBJ2-5     CASSSNGVDTQYF       ND      ND               ND
# 1      TRBV17  TRBJ2-7   CASSRETGNSYEQYF       ND      ND               ND
# 2      TRBV29  TRBJ2-7      CASSLGGYEQYF  TRAV6-4  TRAJ34    CALVPSNTNKVVF
# 3      TRBV29  TRBJ2-5       CASSSSDTQYF  TRAV6-6  TRAJ37  CALG##TGNTGKLIF
# 4      TRBV29  TRBJ2-3       CASSFGGALYF  TRAV6-6  TRAJ53    CALGGGSNYKLTF
# ..        ...      ...               ...      ...     ...              ...
# 491  TRBV12-1  TRBJ2-7  CASSLGLGGNYAEQFF  TRAV9-4  TRAJ21   CAVSAVYGNEKITF
# 492    TRBV17  TRBJ2-5     CASSSNGVDTQYF  TRAV9-4  TRAJ32               ND
# 493    TRBV19  TRBJ1-1     CASSTGANTEVFF  TRAV9-4  TRAJ33   CVLSSXDSNYQLIW
# 494  TRBV12-1  TRBJ2-5    XXXXSXXXXXXXG#  TRAV9-4  TRAJ42    CVXXRGSXXKXXX
# 495       NaN      NaN               NaN    Grand   Total              NaN
#
# ...

# %%
df = df.sort_values(['TRBJ', 'CDR3β', 'Grand Total'])
df
# Out:
#          TRBV     TRBJ            CDR3β      TRAV    TRAJ            CDR3α  \
# 107     TRBV2       ND               ND        ND      ND               ND
# 140        ND       ND               ND    TRAV10  TRAJ33  CAASIS#DSNYQLIW
# 157        ND       ND               ND  TRAV12-2  TRAJ22     CALSSGSWQLIF
# 161        ND       ND               ND  TRAV12-2   TRAJ3    CALSYTNAYKVIF
# 185     TRBV3       ND               ND  TRAV12-3  TRAJ22   CALSESSGSWQLIF
# ..        ...      ...              ...       ...     ...              ...
# 170  TRBV13-2  TRBJ2-7   XXSGGLPSYEQYF   TRAV12-2  TRAJ53  CALSGSGGGNYKXTF
# 348    TRBV29  TRBJ2-7     XXSSLGGYEQYF   TRAV6-4  TRAJ34    CALVPSNTNKVVF
# 468    TRBV14  TRBJ2-7       XXXSPYEQYF   TRAV7-4   TRAJ6    CAASXGGNYKXTF
# 284    TRBV17  TRBJ2-7  XXXXXERGXXXEXXX     TRAV2   TRAJ9  CIVTDK#NMGYKLTF
# 495       NaN      NaN              NaN     Grand   Total              NaN
#
# ...
